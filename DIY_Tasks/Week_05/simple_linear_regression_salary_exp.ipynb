# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read data file
df = pd.read_csv('salary.csv')
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %% [markdown]
# ## Data Exploration & Preprocessing

# %%
df[5:]
# Out:
#     YearsExperience    Salary
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df[5:10]
# Out:
#    YearsExperience   Salary
# 5              2.9  56642.0
# 6              3.0  60150.0
# 7              3.2  54445.0
# 8              3.2  64445.0
# 9              3.7  57189.0

# %%
df.iloc[2] #i=integer, loc=Location based index
# Out:
# YearsExperience        1.5
# Salary             37731.0
# Name: 2, dtype: float64

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Initial 5 records
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
# Last 5 records
df.tail()
# Out:
#     YearsExperience    Salary
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
# Retrieve random file
df.sample()
# Out:
#    YearsExperience   Salary
# 8              3.2  64445.0

# %%
df.sample(3)
# Out:
#     YearsExperience    Salary
# 6               3.0   60150.0
# 14              4.5   61111.0
# 23              8.2  113812.0

# %%
df.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
df.shape
# Out:
# (30, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
# only show discriptive summary of Numerical column
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
df['YearsExperience'].describe()
# Out:
# count    30.000000
# mean      5.313333
# std       2.837888
# min       1.100000
# 25%       3.200000
# 50%       4.700000
# 75%       7.700000
# max      10.500000
# Name: YearsExperience, dtype: float64

# %%
plt.title('Salary Distribution')
plt.xlabel('Amount of Salary')
plt.ylabel('Density')
plt.hist(df['Salary'],bins=5,edgecolor='black',color='green')
plt.show()

# %%
plt.title("Distribution of Years")
plt.xlabel("No. of Years")
plt.ylabel("Density")
plt.hist(df["YearsExperience"], bins=5,edgecolor="black", color="green")
plt.show()

# %%
# Univariate Analysis (One column)
plt.figure(figsize=(8,4))
plt.title('Salary Distribution')
plt.xlabel('Amount of Salary')
plt.ylabel('Density')
sns.histplot(df['Salary'],kde=True) # Kernel Density Estimate
plt.grid(True)
plt.savefig('salary_distribution_histogram.png')
plt.show()

"""It means that in addition to the histogram, Seaborn will plot a smooth curve that estimates the probability density function (PDF) 
of the salary values.

Histogram → Shows the frequency of values in bins.

KDE curve → A smooth approximation of the data distribution, making it easier to see the underlying pattern or trend.

Example: If your salaries are clustered around a certain range, the KDE curve will peak in that area."""
# Out:
# 'It means that in addition to the histogram, Seaborn will plot a smooth curve that estimates the probability density function (PDF) \nof the salary values.\n\nHistogram → Shows the frequency of values in bins.\n\nKDE curve → A smooth approximation of the data distribution, making it easier to see the underlying pattern or trend.\n\nExample: If your salaries are clustered around a certain range, the KDE curve will peak in that area.'

# %%
# Bivariate Analysis 
plt.scatter(df['YearsExperience'],df['Salary'],color='lightcoral')
plt.title("Salary vs Experience")
plt.xlabel('Year of Experience')
plt.ylabel('Salary')
plt.show()

# %%
correlation = df['YearsExperience'].corr(df['Salary'])
print('correlation b/w Experience and Salary',correlation)
# Out:
# correlation b/w Experience and Salary 0.9782416184887599

# %%
# Missing Value
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
X=df.drop(columns=["Salary"])
y=df['Salary']

# %%
X
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
y
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=45)

# %%
X_train
# Out:
#     YearsExperience
# 29             10.5
# 7               3.2
# 10              3.9
# 19              6.0
# 24              8.7
# 6               3.0
# 22              7.9
# 23              8.2
# 18              5.9
# 17              5.3
# 2               1.5
# 12              4.0
# 20              6.8
# 26              9.5
# 8               3.2
# 14              4.5
# 1               1.3
# 15              4.9
# 4               2.2
# 28             10.3
# 21              7.1
# 0               1.1
# 3               2.0
# 11              4.0

# %%
len(X_train)
# Out:
# 24

# %%
X_test
# Out:
#     YearsExperience
# 16              5.1
# 27              9.6
# 25              9.0
# 5               2.9
# 13              4.1
# 9               3.7

# %%
len(X_test)
# Out:
# 6

# %%
y_train
# Out:
# 29    121872.0
# 7      54445.0
# 10     63218.0
# 19     93940.0
# 24    109431.0
# 6      60150.0
# 22    101302.0
# 23    113812.0
# 18     81363.0
# 17     83088.0
# 2      37731.0
# 12     56957.0
# 20     91738.0
# 26    116969.0
# 8      64445.0
# 14     61111.0
# 1      46205.0
# 15     67938.0
# 4      39891.0
# 28    122391.0
# 21     98273.0
# 0      39343.0
# 3      43525.0
# 11     55794.0
# Name: Salary, dtype: float64

# %%
len(y_train)
# Out:
# 24

# %%
y_test
# Out:
# 16     66029.0
# 27    112635.0
# 25    105582.0
# 5      56642.0
# 13     57081.0
# 9      57189.0
# Name: Salary, dtype: float64

# %%
len(y_test)
# Out:
# 6

# %%
from sklearn.linear_model import LinearRegression

# %%
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression
reg = LinearRegression()

# %%
reg
# Out:
# LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)
y_pred
# Out:
# array([ 74997.87116706, 118237.8380738 , 112472.5091529 ,  53858.33179043,
#         65388.98963223,  61545.4370183 ])

# %%
pd.DataFrame({'y_test':y_test, 'y_pred':y_pred,'MAE':(y_test-y_pred)})
# Out:
#       y_test         y_pred          MAE
# 16   66029.0   74997.871167 -8968.871167
# 27  112635.0  118237.838074 -5602.838074
# 25  105582.0  112472.509153 -6890.509153
# 5    56642.0   53858.331790  2783.668210
# 13   57081.0   65388.989632 -8307.989632
# 9    57189.0   61545.437018 -4356.437018

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
print('MSE = ', mean_squared_error(y_test, y_pred ))
print('RMSE = ', np.sqrt(mean_squared_error(y_test, y_pred )))
print('R2 = ', r2_score(y_test, y_pred ))
# Out:
# MSE =  42510267.467214905
# RMSE =  6519.989836434939
# R2 =  0.9250487875802145

# %%
"""[[10]] → a 2D array (one sample with one feature value = 10).

Returns → the predicted y value based on the model's learned coefficients and intercept."""

import warnings
warnings.filterwarnings("ignore", category=UserWarning)

reg.predict([[10]])
# Out:
# array([122081.39068773])

# %%
reg.predict([[25]])
# Out:
# array([266214.61371019])

# %%
print ("Intercept value:",reg.intercept_)
print ("Slope value:",reg.coef_)
print("y= mX","+","C")
print("y=",reg.coef_,"*",+reg.intercept_)
# Out:
# Intercept value: 25992.575339423667
# Slope value: [9608.88153483]
# y= mX + C
# y= [9608.88153483] * 25992.575339423667

# %%
plt.scatter(X_train,y_train)
plt.plot(X_test,y_pred,color='r')
plt.title("Salary vs YearsExperience")
plt.xlabel("Year of Experience")
plt.ylabel("Salary")
plt.show()

# %%
plt.scatter(X_test,y_test)
plt.plot(X_test,y_pred,color='r')
plt.title("Salary vs YearsExperience")
plt.xlabel("Year of Experience")
plt.ylabel("Salary")
plt.show()
